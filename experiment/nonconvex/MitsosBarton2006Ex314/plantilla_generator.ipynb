# %% [markdown]
# ## Importar el módulo

# %%
include("../../new_experiment.jl")
# Out:
# RunExperiment

# %% [markdown]
# Crear un experimento

# %%
experiment=CreateExperiment()
# Out:
# Experiment(OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[1], false), OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[], true), Any[], Any[])

# %% [markdown]
# ### Declarar variables del líder

# %%
@leader_vars experiment x
# Out:
# 1-element Vector{Num}:
#  x

# %% [markdown]
# ### Declarar Variables del Follower

# %%
@follower_vars experiment y
# Out:
# 1-element Vector{Num}:
#  y

# %% [markdown]
# ### Declarar Función Objetivo del Líder

# %%
SetLeaderFunction(experiment,((x-0.25)^2)+(y^2))
# Out:
# (-0.25 + x)^2 + y^2

# %% [markdown]
# Restricciones del Líder

# %%
SetLeaderRestriction(experiment,x-1<=0)
# Out:
# 1-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 + x) <= 0, 0.75, J_0_g)

# %%
SetLeaderRestriction(experiment,-x-1<=0)
# Out:
# 2-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 + x) <= 0, 0.75, J_0_g)
#  LeaderRestrictionProblem((-1 - x) <= 0, 0.49, J_0_g)

# %% [markdown]
# ### Función objetivo del Follower

# %%
SetFollowerFunction(experiment,((1/3)*(y^3))-(x*y))
# Out:
# -x*y + 0.3333333333333333(y^3)

# %% [markdown]
# ### Restricciones del Follower

# %%
SetFollowerRestriction(experiment,y-1<=0)
# Out:
# 1-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.8, 0.65, 0.83)

# %%
SetFollowerRestriction(experiment,-y-1<=0)
# Out:
# 2-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.8, 0.65, 0.83)
#  FollowerRestrictionProblem((-1 - y) <= 0, J_0_LP_v, 0.21, 0.57, 0.59)

# %% [markdown]
# ### Poner el Punto Optimo

# %%
SetPoint(experiment,Dict(x=>0.25,y=>0.5))
# Out:
# Dict{Any, Any} with 2 entries:
#   y => 3.55
#   x => 4.3

# %% [markdown]
# ## Iniciar el Experimento

# %%
RunExperiment(experiment,"MitsosBarton2006Ex314",true)
# Out:
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + 0.004629644907760855y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.983564760577449
# Additional constant: 0.983564760577449
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.8
# Value of lambda: 0.65
# Value of gamma: 0.83
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.004629644907760855y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -1.016435239422551
# Additional constant: 1.016435239422551
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.21
# Value of lambda: 0.57
# Value of gamma: 0.59
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-7.364629644907762, -14.169861011650477]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 2.55
# Additional constant: -2.55
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0.027150510402551564
# Value of lambda: 0.65
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -4.55
# Additional constant: 4.55
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 1.7036293653534984
# Value of lambda: 0.57
# Value of gamma: 1.5106827443380266
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-8.360000000000001, -5.423521145049053]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + 12.283122987949962y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 42.60508660722236
# Additional constant: -42.60508660722236
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.65
# Value of gamma: 2.9335395290608393
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.7611731534448762y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -3.7021646947293103
# Additional constant: 3.7021646947293103
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 5.433848077011133
# Value of lambda: 0.57
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-8.121173153444877, -4.659571334422438]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 2.55
# Additional constant: -2.55
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0.027150510402551564
# Value of lambda: 0.65
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -4.55
# Additional constant: 4.55
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 1.7036293653534984
# Value of lambda: 0.57
# Value of gamma: 1.5106827443380266
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-8.360000000000001, -5.423521145049053]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + 3.2476850002583872y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 10.529281750917274
# Additional constant: -10.529281750917274
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.65
# Value of gamma: 2.9335395290608393
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.09672904581957753y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -1.3433881126595002
# Additional constant: 1.3433881126595002
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 5.433848077011133
# Value of lambda: 0.57
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-7.4567290458195785, -12.987612835063166]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 2.55
# Additional constant: -2.55
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 9.7
# Value of lambda: 0.65
# Value of gamma: 0.8
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -4.55
# Additional constant: 4.55
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 7.1
# Value of lambda: 0.57
# Value of gamma: 5.4
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-8.360000000000001, -9.7]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -1
# Additional constant: 1
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 6.9679412671287295
# Value of lambda: 0.65
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.47515587738203025y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -2.6868033647062073
# Additional constant: 2.6868033647062073
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 2.6204050180134733
# Value of lambda: 0.57
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-7.835155877382031, -9.581292425157118]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 2.55
# Additional constant: -2.55
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 9.7
# Value of lambda: 0.65
# Value of gamma: 0.8
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -4.55
# Additional constant: 4.55
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 7.1
# Value of lambda: 0.57
# Value of gamma: 5.4
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-8.360000000000001, -9.7]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -1
# Additional constant: 1
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 6.9679412671287295
# Value of lambda: 0.65
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.5487863166809178y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -2.948191424217258
# Additional constant: 2.948191424217258
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 2.6204050180134733
# Value of lambda: 0.57
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-7.908786316680919, -8.865574733517676]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 2.55
# Additional constant: -2.55
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 6.0
# Value of lambda: 0.65
# Value of gamma: 8.4
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -4.55
# Additional constant: 4.55
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 7.6
# Value of lambda: 0.57
# Value of gamma: 1.1
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-8.360000000000001, -5.5]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + 8.35480283041278y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 28.659550047965368
# Additional constant: -28.659550047965368
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 2.9
# Value of lambda: 0.65
# Value of gamma: 7.800000000000001
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.06640525715259382y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -1.235738662891708
# Additional constant: 1.235738662891708
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 1.4000000000000001
# Value of lambda: 0.57
# Value of gamma: 0.7000000000000001
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-7.426405257152595, -37.864483522400015]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 29.005000000000006
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 3.3000000000000007
# Additional constant: -3.3000000000000007
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.75
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -5.300000000000001
# Additional constant: 5.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.49
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -0.3520416666666719
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: 2.55
# Additional constant: -2.55
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 6.0
# Value of lambda: 0.65
# Value of gamma: 8.4
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# Evaluation value: -4.55
# Additional constant: 4.55
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 7.6
# Value of lambda: 0.57
# Value of gamma: 1.1
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 4.300000000000001, "y" => 3.55)
# ------------------------------
# _
#
# Num[-8.360000000000001, -5.5]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Finilizado el experimento completo
