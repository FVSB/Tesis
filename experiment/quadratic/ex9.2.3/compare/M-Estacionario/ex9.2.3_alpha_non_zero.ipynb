# %% [markdown]
# # Importar las depencias necesarias

# %%
include("../../../../experiment.jl")

# %%
using BilevelJuMP

# %%
model=BilevelModel()
# Out:
# An Abstract JuMP Model
# Feasibility problem with:
# Variables: 0
# Upper Constraints: 0
# Lower Constraints: 0
# Bilevel Model
# Solution method: BilevelJuMP.NoMode{Float64}
# No solver attached

# %% [markdown]
# ## Definir variables

# %%
BilevelJuMP.@variable(Upper(model),0<=x[1:2]<=50)
BilevelJuMP.@variable(Lower(model),-10<=y[1:2]<=20)
# Out:
# 2-element Vector{BilevelVariableRef}:
#  y[1]
#  y[2]

# %% [markdown]
# ## Definir nivel superior

# %%
BilevelJuMP.@objective(Upper(model),Min,2x[1]+2x[2]-3y[1]-3y[2]-60)
# Out:
# 2 x[1] + 2 x[2] - 3 y[1] - 3 y[2] - 60

# %%
BilevelJuMP.@constraints(Upper(model),begin
a1,x[1]+x[2]+y[1]-2y[2]-16.45<=0
end)
# Out:
# (a1 : x[1] + x[2] + y[1] - 2 y[2] ≤ 16.45,)

# %% [markdown]
# ## Definir Nivel inferior

# %%
BilevelJuMP.@objective(Lower(model),Min,(y[1]-x[1]+20)^2+(y[2]-x[2]+20)^2)
# Out:
# y[1]² - 2 x[1]*y[1] + x[1]² + y[2]² - 2 x[2]*y[2] + x[2]² + 40 y[1] - 40 x[1] + 40 y[2] - 40 x[2] + 800

# %%
BilevelJuMP.@constraints(Lower(model),begin
c1,20.12839819112222 - x[1] + 0.08539807211710101y[1] + 2.0974413899797693y[2]<=0
c2,5.159464476972512 - x[2] - 0.991360228489825y[1] + 0.8688325598000715y[2]<=0
c3,24.469905985957396 + 0.9752945376651194y[1] + 2.25386171605379y[2]<=0
c4,-17.988035658026536 - 0.5423001595735621y[1] - 1.7598040282313723y[2]<=0
c5,-41.5591050815185 + 2.0179935737236696y[1] + 1.3025824110436748y[2]<=0
c6,-41.785557538974174 - 0.45855051767225985y[1] + 0.47678210163037016y[2]<=0
end)
# Out:
# (c1 : -x[1] + 0.08539807211710101 y[1] + 2.0974413899797693 y[2] ≤ -20.12839819112222, c2 : -x[2] - 0.991360228489825 y[1] + 0.8688325598000715 y[2] ≤ -5.159464476972512, c3 : 0.9752945376651194 y[1] + 2.25386171605379 y[2] ≤ -24.469905985957396, c4 : -0.5423001595735621 y[1] - 1.7598040282313723 y[2] ≤ 17.988035658026536, c5 : 2.0179935737236696 y[1] + 1.3025824110436748 y[2] ≤ 41.5591050815185, c6 : -0.45855051767225985 y[1] + 0.47678210163037016 y[2] ≤ 41.785557538974174)

# %% [markdown]
# ## Run

# %%
start_experiment(model,x,y,"ex9.2.3(Quadratic)_alpha_non_zero")
# Out:
# Resolviendo el problema con HiGHS
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [9e-02, 1e+02]
#   Cost   [2e+00, 3e+00]
#   Bound  [1e+00, 5e+01]
#   RHS    [5e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of          20 from [lower, value, upper] = [             40;              20;              40]
# WARNING: Row      6 has         infeasibility of       41.97 from [lower, value, upper] = [      41.785558;     -0.18231584;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities     10        74.76        237.7
# Row     residuals            0            0            0
# ...
