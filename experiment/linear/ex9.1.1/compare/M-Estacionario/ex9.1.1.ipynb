# %% [markdown]
# # Importar las depencias necesarias

# %%
include("../../../../experiment.jl")

# %%
using BilevelJuMP

# %%
model = BilevelModel()
# Out:
# An Abstract JuMP Model
# Feasibility problem with:
# Variables: 0
# Upper Constraints: 0
# Lower Constraints: 0
# Bilevel Model
# Solution method: BilevelJuMP.NoMode{Float64}
# No solver attached

# %% [markdown]
# Definir variables

# %%
BilevelJuMP.@variable(Upper(model), 0<=x<=8)
BilevelJuMP.@variable(Lower(model), 0<=y[1:2]<=4)
# Out:
# 2-element Vector{BilevelVariableRef}:
#  y[1]
#  y[2]

# %% [markdown]
# ### Nivel superior

# %%
BilevelJuMP.@objective(Upper(model),Min,-x-3y[1]+2y[2])
# Out:
# -x - 3 y[1] + 2 y[2]

# %% [markdown]
# ### Nivel inferior

# %%
BilevelJuMP.@objective(Lower(model),Min,-y[1])
BilevelJuMP.@constraints(Lower(model),begin
c1,0.9270360882359463y[1] + 0.989582907613092y[2]<=0
c2,-4 + 0.8965435170293287y[1] - 0.05312758170671375y[2]<=0
c3,-16 - 2x - 0.32852662910738983y[1] + 3.3177671905060135y[2]<=0
c4,-48 + 8x + 0.20867847500363246y[1] - 0.4063640843797479y[2]<=0
c5,12 - 2x - 0.4173569500072649y[1] + 0.8127281687594958y[2]<=0

end)
# Out:
# (c1 : 0.9270360882359463 y[1] + 0.989582907613092 y[2] ≤ 0, c2 : 0.8965435170293287 y[1] - 0.05312758170671375 y[2] ≤ 4, c3 : -2 x - 0.32852662910738983 y[1] + 3.3177671905060135 y[2] ≤ 16, c4 : 8 x + 0.20867847500363246 y[1] - 0.4063640843797479 y[2] ≤ 48, c5 : -2 x - 0.4173569500072649 y[1] + 0.8127281687594958 y[2] ≤ -12)

# %% [markdown]
# Notas: restricciones del follower : Lineales

# %%
start_experiment(model,[x],y,"ex9.1.1(Linear)_Alpha_non_zero")
# Out:
# Resolviendo el problema con HiGHS
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.02 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# optimize Method: Highs-BigM (100,100)
# Primal Status: FEASIBLE_POINT
# Termination Status: OPTIMAL
# Objetive Value -6.0
# Lider Vars: [6.0]
# Followers Vars Value [0.0, 0.0]
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# ...
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      2 has         infeasibility of           4 from [lower, value, upper] = [              4;               0;             inf]
# WARNING: Row      4 has         infeasibility of          16 from [lower, value, upper] = [             16;               0;             inf]
# WARNING: Row     12 has         infeasibility of          48 from [lower, value, upper] = [             48;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      7           48           89
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [4e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# 7 rows, 5 cols, 13 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# 2 rows, 4 cols, 6 nonzeros  0s
# Objective function is integral with scale 1
#
# Solving MIP model with:
#    2 rows
#    4 cols (0 binary, 0 integer, 0 implied int., 4 continuous)
#    6 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -6              inf                  inf        0      0      0         0     0.0s
#  T       0       0         0 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#          1       0         1 100.00%   -6              -6                 0.00%        0      0      0         2     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      -6
#   Dual bound        -6
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0
#   Solution status   feasible
#                     -6 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     2 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [5e-02, 1e+02]
#   Cost   [1e+00, 3e+00]
#   Bound  [1e+00, 8e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# Coefficient ranges:
# El DataFrame ha sido guardado en ex9.1.1(Linear)_Alpha_non_zero.xlsx en la hoja ex9.1.1(Linear)_Alpha_non_zero.
# Resolviendo el problema con SOS1
# presolving:
# (round 1, fast)       9 del vars, 11 del conss, 0 add conss, 17 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 2, fast)       12 del vars, 14 del conss, 0 add conss, 22 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 3, medium)     16 del vars, 23 del conss, 0 add conss, 22 chg bounds, 0 chg sides, 5 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
#    (0.0s) symmetry computation started: requiring (bin +, int +, cont +), (fixed: bin -, int -, cont -)
#    (0.0s) no symmetry present
# presolving (4 rounds: 4 fast, 2 medium, 1 exhaustive):
#  16 deleted vars, 23 deleted constraints, 0 added constraints, 22 tightened bounds, 0 added holes, 0 changed sides, 5 changed coefficients
#  0 implications, 0 cliques
# presolved problem has 5 variables (0 bin, 0 int, 0 impl, 5 cont) and 2 constraints
#       2 constraints of type <linear>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 0.00
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# * 0.0s|     1 |     0 |     2 |     - |    LP  |   0 |   5 |   2 |   2 |   0 |  0 |   0 |   0 |-6.000000e+00 |-6.000000e+00 |   0.00%| unknown
#   0.0s|     1 |     0 |     2 |     - |   677k |   0 |   5 |   2 |   2 |   0 |  0 |   0 |   0 |-6.000000e+00 |-6.000000e+00 |   0.00%| unknown
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 0.00
# Solving Nodes      : 1
# Primal Bound       : -6.00000000000000e+00 (1 solutions)
# Dual Bound         : -6.00000000000000e+00
# Gap                : 0.00 %
# optimize Method: SOS1
# Primal Status: FEASIBLE_POINT
# Termination Status: OPTIMAL
# Objetive Value -6.0
