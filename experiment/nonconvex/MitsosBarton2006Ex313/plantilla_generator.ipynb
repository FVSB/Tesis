# %% [markdown]
# ## Importar el módulo

# %%
include("../../new_experiment.jl")
# Out:
# RunExperiment

# %%
using Random

# Random seed
Random.seed!(7)

# %% [markdown]
# Crear un experimento

# %%
experiment=CreateExperiment()
# Out:
# Experiment(OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[1], false), OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[], true), Any[], Any[])

# %% [markdown]
# ### Declarar variables del líder

# %%
@leader_vars experiment x
# Out:
# 1-element Vector{Num}:
#  x

# %% [markdown]
# ### Declarar Variables del Follower

# %%
@follower_vars experiment y
# Out:
# 1-element Vector{Num}:
#  y

# %% [markdown]
# ### Declarar Función Objetivo del Líder

# %%
SetLeaderFunction(experiment,x-y)
# Out:
# x - y

# %% [markdown]
# Restricciones del Líder

# %%
SetLeaderRestriction(experiment,-x-1<=0)
# Out:
# 1-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 - x) <= 0, 0.51, J_0_g)

# %%
SetLeaderRestriction(experiment,x-1<=0)
# Out:
# 2-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 - x) <= 0, 0.51, J_0_g)
#  LeaderRestrictionProblem((-1 + x) <= 0, 0.17, J_0_g)

# %% [markdown]
# ### Función objetivo del Follower

# %%
SetFollowerFunction(experiment,(0.5x*(y^2))-((x^3)*y))
# Out:
# 0.5x*(y^2) - (x^3)*y

# %% [markdown]
# ### Restricciones del Follower

# %%
SetFollowerRestriction(experiment,y-1<=0)
# Out:
# 1-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.8, 0.82, 0.13)

# %%
SetFollowerRestriction(experiment,-y-1<=0)
# Out:
# 2-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.8, 0.82, 0.13)
#  FollowerRestrictionProblem((-1 - y) <= 0, J_0_LP_v, 0.46, 0.81, 0.74)

# %% [markdown]
# ### Poner el Punto Optimo

# %%
SetPoint(experiment,Dict(x=>0,y=>1))
# Out:
# Dict{Any, Any} with 2 entries:
#   y => 4.45
#   x => 2.3

# %% [markdown]
# ## Iniciar el Experimento

# %%
RunExperiment(experiment,"MitsosBarton2006Ex313",true)
# Out:
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: 5.162 - 1.1600000000000001y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -6.162
# Additional constant: 6.162
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.8
# Value of lambda: 0.82
# Value of gamma: 0.13
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -5.162 + 1.1600000000000001y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 4.162
# Additional constant: -4.162
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.46
# Value of lambda: 0.81
# Value of gamma: 0.74
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[24.007200000000008, -3.5736000000000008]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -4.449999999999999 + y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 3.4499999999999993
# Additional constant: -3.4499999999999993
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 1.7000000000000002
# Value of lambda: 0.82
# Value of gamma: 8.5
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 4.449999999999999 - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -5.449999999999999
# Additional constant: 5.449999999999999
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.81
# Value of gamma: 5.1
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[-0.66, -0.7000000000000002]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# Carpeta creada: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: 3.9796747967479664 - 0.8943089430894309y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -4.979674796747966
# Additional constant: 4.979674796747966
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -1.1
# Value of lambda: 0.82
# Value of gamma: -1.1
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1.0234999999999999 + 0.22999999999999998y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 0.023499999999999854
# Additional constant: -0.023499999999999854
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 7.6
# Value of lambda: 0.81
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[13.386600000000003, -4.5607398373983745]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -4.449999999999999 + y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 3.4499999999999993
# Additional constant: -3.4499999999999993
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 1.7000000000000002
# Value of lambda: 0.82
# Value of gamma: 8.5
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 4.449999999999999 - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -5.449999999999999
# Additional constant: 5.449999999999999
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.81
# Value of gamma: 5.1
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[-0.66, -0.7000000000000002]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: 2.4353233830845764 - 0.5472636815920398y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.4353233830845764
# Additional constant: 3.4353233830845764
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -1.1
# Value of lambda: 0.82
# Value of gamma: -1.1
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -4.4945 + 1.0100000000000002y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 3.4945000000000004
# Additional constant: -3.4945000000000004
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 7.6
# Value of lambda: 0.81
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[22.29420000000001, -11.900990049751247]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -4.449999999999999 + y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 3.4499999999999993
# Additional constant: -3.4499999999999993
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 6.7
# Value of lambda: 0.82
# Value of gamma: 1.7000000000000002
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 4.449999999999999 - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -5.449999999999999
# Additional constant: 5.449999999999999
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 8.4
# Value of lambda: 0.81
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[-0.66, 2.7]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: 0
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -1
# Additional constant: 1
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.4000000000000004
# Value of lambda: 0.82
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -4.761499999999999 + 1.0699999999999998y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 3.761499999999999
# Additional constant: -3.761499999999999
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 6.0
# Value of lambda: 0.81
# Value of gamma: 7.199999999999999
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[22.979400000000005, -10.181]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -4.449999999999999 + y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 3.4499999999999993
# Additional constant: -3.4499999999999993
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 6.7
# Value of lambda: 0.82
# Value of gamma: 1.7000000000000002
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 4.449999999999999 - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -5.449999999999999
# Additional constant: 5.449999999999999
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 8.4
# Value of lambda: 0.81
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[-0.66, 2.7]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: 0
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -1
# Additional constant: 1
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.4000000000000004
# Value of lambda: 0.82
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 2.981499999999999 - 0.6699999999999999y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.981499999999999
# Additional constant: 3.981499999999999
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 6.0
# Value of lambda: 0.81
# Value of gamma: 7.199999999999999
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[3.1086000000000014, 4.260999999999999]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -4.449999999999999 + y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 3.4499999999999993
# Additional constant: -3.4499999999999993
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.2
# Value of lambda: 0.82
# Value of gamma: 9.8
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 4.449999999999999 - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -5.449999999999999
# Additional constant: 5.449999999999999
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 7.199999999999999
# Value of lambda: 0.81
# Value of gamma: 1.7000000000000002
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[-0.66, 4.999999999999999]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -10.877777777777776 + 2.4444444444444446y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 9.877777777777776
# Additional constant: -9.877777777777776
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.7
# Value of lambda: 0.82
# Value of gamma: 5.5
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -5.562499999999999 + 1.25y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 4.562499999999999
# Additional constant: -4.562499999999999
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 7.199999999999999
# Value of lambda: 0.81
# Value of gamma: 1.0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[25.035000000000007, -22.219444444444445]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -2.149999999999999
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.3000000000000003 - x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -3.3000000000000003
# Additional constant: 3.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.51
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.3000000000000003 + x
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 1.3000000000000003
# Additional constant: -1.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.17
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -31.37027500000001
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -4.449999999999999 + y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: 3.4499999999999993
# Additional constant: -3.4499999999999993
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.2
# Value of lambda: 0.82
# Value of gamma: 9.8
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 4.449999999999999 - y
# Evaluation point: Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# Evaluation value: -5.449999999999999
# Additional constant: 5.449999999999999
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 7.199999999999999
# Value of lambda: 0.81
# Value of gamma: 1.7000000000000002
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.3000000000000003, "y" => 4.449999999999999)
# ------------------------------
# _
#
# Num[-0.66, 4.999999999999999]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Finilizado el experimento completo
