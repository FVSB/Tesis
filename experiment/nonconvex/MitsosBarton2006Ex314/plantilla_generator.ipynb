# %% [markdown]
# ## Importar el módulo

# %%
include("../../new_experiment.jl")
# Out:
# RunExperiment

# %% [markdown]
# Crear un experimento

# %%
experiment=CreateExperiment()
# Out:
# Experiment(OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[1], false), OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[], true), Any[], Any[])

# %% [markdown]
# ### Declarar variables del líder

# %%
@leader_vars experiment x
# Out:
# 1-element Vector{Num}:
#  x

# %% [markdown]
# ### Declarar Variables del Follower

# %%
@follower_vars experiment y
# Out:
# 1-element Vector{Num}:
#  y

# %% [markdown]
# ### Declarar Función Objetivo del Líder

# %%
SetLeaderFunction(experiment,((x-0.25)^2)+(y^2))
# Out:
# (-0.25 + x)^2 + y^2

# %% [markdown]
# Restricciones del Líder

# %%
SetLeaderRestriction(experiment,x-1<=0)
# Out:
# 1-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 + x) <= 0, 0.74, J_0_g)

# %%
SetLeaderRestriction(experiment,-x-1<=0)
# Out:
# 2-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 + x) <= 0, 0.74, J_0_g)
#  LeaderRestrictionProblem((-1 - x) <= 0, 0.27, J_0_g)

# %% [markdown]
# ### Función objetivo del Follower

# %%
SetFollowerFunction(experiment,((1/3)*(y^3))-(x*y))
# Out:
# -x*y + 0.3333333333333333(y^3)

# %% [markdown]
# ### Restricciones del Follower

# %%
SetFollowerRestriction(experiment,y-1<=0)
# Out:
# 1-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.97, 0.22, 0.56)

# %%
SetFollowerRestriction(experiment,-y-1<=0)
# Out:
# 2-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.97, 0.22, 0.56)
#  FollowerRestrictionProblem((-1 - y) <= 0, J_0_LP_v, 0.37, 0.66, 0.33)

# %% [markdown]
# ### Poner el Punto Optimo

# %%
SetPoint(experiment,Dict(x=>0.25,y=>0.5))
# Out:
# Dict{Any, Any} with 2 entries:
#   y => 3.3
#   x => 2.1

# %% [markdown]
# ## Iniciar el Experimento

# %%
RunExperiment(experiment,"MitsosBarton2006Ex314",true)
# Out:
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -2.607 + 0.79y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.6070000000000002
# Additional constant: -1.6070000000000002
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.97
# Value of lambda: 0.22
# Value of gamma: 0.56
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 2.607 - 0.79y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.607
# Additional constant: 3.607
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.37
# Value of lambda: 0.66
# Value of gamma: 0.33
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-3.96, -8.46]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -3.3000000000000003 + y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 2.3000000000000003
# Additional constant: -2.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -3.5
# Value of lambda: 0.22
# Value of gamma: -6.0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 3.3000000000000007 - y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -4.300000000000001
# Additional constant: 4.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: -4.9
# Value of lambda: 0.66
# Value of gamma: -6.800000000000001
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-4.17, -8.0]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# Carpeta creada: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -51.117647058823536 + 15.490196078431374y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 50.117647058823536
# Additional constant: -50.117647058823536
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.22
# Value of gamma: 7.9
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 1.617 - 0.49y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -2.617
# Additional constant: 2.617
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: -2.5
# Value of lambda: 0.66
# Value of gamma: -7.199999999999999
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-3.66, -11.191]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -3.3000000000000003 + y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 2.3000000000000003
# Additional constant: -2.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -3.5
# Value of lambda: 0.22
# Value of gamma: -6.0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 3.3000000000000007 - y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -4.300000000000001
# Additional constant: 4.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: -4.9
# Value of lambda: 0.66
# Value of gamma: -6.800000000000001
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-4.17, -8.0]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -62.07142857142858 + 18.80952380952381y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 61.07142857142858
# Additional constant: -61.07142857142858
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.22
# Value of gamma: 7.9
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 1.9139999999999997 - 0.58y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -2.9139999999999997
# Additional constant: 2.9139999999999997
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: -2.5
# Value of lambda: 0.66
# Value of gamma: -7.199999999999999
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-3.75, -10.822000000000001]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -3.3000000000000003 + y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 2.3000000000000003
# Additional constant: -2.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0.8
# Value of lambda: 0.22
# Value of gamma: 6.2
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 3.3000000000000007 - y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -4.300000000000001
# Additional constant: 4.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.66
# Value of gamma: 7.800000000000001
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-4.17, -7.4]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -0.8354430379746837 + 0.25316455696202533y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -0.16455696202531633
# Additional constant: 0.16455696202531633
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 1.4000000000000001
# Value of lambda: 0.22
# Value of gamma: 0.6
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -4.521000000000001 + 1.37y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 3.521000000000001
# Additional constant: -3.521000000000001
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.66
# Value of gamma: 9.399999999999999
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-1.7999999999999998, -22.596430379746835]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -3.3000000000000003 + y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 2.3000000000000003
# Additional constant: -2.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0.8
# Value of lambda: 0.22
# Value of gamma: 6.2
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 3.3000000000000007 - y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -4.300000000000001
# Additional constant: 4.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.66
# Value of gamma: 7.800000000000001
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-4.17, -7.4]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -0.9041095890410963 + 0.2739726027397261y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -0.09589041095890372
# Additional constant: 0.09589041095890372
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 1.4000000000000001
# Value of lambda: 0.22
# Value of gamma: 0.6
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -3.927 + 1.19y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 2.927
# Additional constant: -2.927
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.66
# Value of gamma: 9.399999999999999
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-1.98, -21.43756164383562]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -3.3000000000000003 + y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 2.3000000000000003
# Additional constant: -2.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 7.1
# Value of lambda: 0.22
# Value of gamma: 0.3
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 3.3000000000000007 - y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -4.300000000000001
# Additional constant: 4.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 8.8
# Value of lambda: 0.66
# Value of gamma: 3.1
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-4.17, -4.8999999999999995]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -10.025316455696203 + 3.0379746835443036y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 9.025316455696203
# Additional constant: -9.025316455696203
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.8
# Value of lambda: 0.22
# Value of gamma: 7.199999999999999
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -4.521000000000001 + 1.37y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 3.521000000000001
# Additional constant: -3.521000000000001
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 6.0
# Value of lambda: 0.66
# Value of gamma: 4.4
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-1.7999999999999998, -42.006303797468355]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 14.312500000000004
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -2.1 + x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 1.1
# Additional constant: -1.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.74
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: 2.1 - x
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -3.1
# Additional constant: 3.1
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.27
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 5.049000000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -3.3000000000000003 + y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: 2.3000000000000003
# Additional constant: -2.3000000000000003
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 7.1
# Value of lambda: 0.22
# Value of gamma: 0.3
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: 3.3000000000000007 - y
# Evaluation point: Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# Evaluation value: -4.300000000000001
# Additional constant: 4.300000000000001
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 8.8
# Value of lambda: 0.66
# Value of gamma: 3.1
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 2.1, "y" => 3.3000000000000003)
# ------------------------------
# _
#
# Num[-4.17, -4.8999999999999995]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Finilizado el experimento completo
