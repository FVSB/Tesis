# %% [markdown]
# ## Importar el módulo

# %%
include("../../new_experiment.jl")
# Out:
# RunExperiment

# %% [markdown]
# Crear un experimento

# %%
experiment=CreateExperiment()
# Out:
# Experiment(OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[1], false), OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[], true), Any[], Any[])

# %% [markdown]
# ### Declarar variables del líder

# %%
@leader_vars experiment x
# Out:
# 1-element Vector{Num}:
#  x

# %% [markdown]
# ### Declarar Variables del Follower

# %%
@follower_vars experiment y
# Out:
# 1-element Vector{Num}:
#  y

# %% [markdown]
# ### Declarar Función Objetivo del Líder

# %%
SetLeaderFunction(experiment,x-y)
# Out:
# x - y

# %% [markdown]
# Restricciones del Líder

# %%
SetLeaderRestriction(experiment,-x-1<=0)
# Out:
# 1-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 - x) <= 0, 0.73, J_0_g)

# %%
SetLeaderRestriction(experiment,x-1<=0)
# Out:
# 2-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 - x) <= 0, 0.73, J_0_g)
#  LeaderRestrictionProblem((-1 + x) <= 0, 0.64, J_0_g)

# %% [markdown]
# ### Función objetivo del Follower

# %%
SetFollowerFunction(experiment,(0.5x*(y^2))-((x^3)*y))
# Out:
# 0.5x*(y^2) - (x^3)*y

# %% [markdown]
# ### Restricciones del Follower

# %%
SetFollowerRestriction(experiment,y-1<=0)
# Out:
# 1-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.31, 0.07, 0.78)

# %%
SetFollowerRestriction(experiment,-y-1<=0)
# Out:
# 2-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.31, 0.07, 0.78)
#  FollowerRestrictionProblem((-1 - y) <= 0, J_0_LP_v, 0.66, 0.82, 0.2)

# %% [markdown]
# ### Poner el Punto Optimo

# %%
SetPoint(experiment,Dict(x=>0,y=>1))
# Out:
# Dict{Any, Any} with 2 entries:
#   y => 2.65
#   x => 1.8

# %% [markdown]
# ## Iniciar el Experimento

# %%
RunExperiment(experiment,"MitsosBarton2006Ex313",true)
# Out:
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + 0.7372060335982663y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.953595989035406
# Additional constant: -0.953595989035406
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.31
# Value of lambda: 0.07
# Value of gamma: 0.78
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.7372060335982663y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.953595989035406
# Additional constant: 2.953595989035406
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.66
# Value of lambda: 0.82
# Value of gamma: 0.2
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[0.9479533424602568, 0.7849929722362727]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 1.6500000000000004
# Additional constant: -1.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 4.622313460180284
# Value of lambda: 0.07
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -3.6500000000000004
# Additional constant: 3.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: -9.775891877472372
# Value of lambda: 0.82
# Value of gamma: -9.417582308694728
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[-0.91, -13.398205337652655]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 - 12.496867819078878y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -34.11669972055903
# Additional constant: 34.11669972055903
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -3.0831527603770423
# Value of lambda: 0.07
# Value of gamma: -5.131867721848989
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.5893476832639453y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.5617713606494554
# Additional constant: 2.5617713606494554
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 5.815286436845256
# Value of lambda: 0.82
# Value of gamma: 4.145764709894456
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[1.9933118793239064, -34.841701093513976]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 1.6500000000000004
# Additional constant: -1.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 4.622313460180284
# Value of lambda: 0.07
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -3.6500000000000004
# Additional constant: 3.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: -9.775891877472372
# Value of lambda: 0.82
# Value of gamma: -9.417582308694728
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[-0.91, -13.398205337652655]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 - 45.52060137915968y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -121.62959365477316
# Additional constant: 121.62959365477316
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -3.0831527603770423
# Value of lambda: 0.07
# Value of gamma: -5.131867721848989
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.8872627433213466y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -3.351246269801569
# Additional constant: 3.351246269801569
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 5.815286436845256
# Value of lambda: 0.82
# Value of gamma: 4.145764709894456
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[-0.11294759528192055, -134.390207861046]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 1.6500000000000004
# Additional constant: -1.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.07
# Value of gamma: 6.8365717750666395
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -3.6500000000000004
# Additional constant: 3.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 5.75442747615179
# Value of lambda: 0.82
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[-0.91, 6.75442747615179]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -1
# Additional constant: 1
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.6246212298263734
# Value of lambda: 0.07
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.8748783419798819y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -3.3184276062466873
# Additional constant: 3.3184276062466873
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.82
# Value of gamma: 0.7489593364149039
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[-0.025389877797765248, 0.7747810155637874]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 1.6500000000000004
# Additional constant: -1.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.07
# Value of gamma: 6.8365717750666395
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -3.6500000000000004
# Additional constant: 3.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 5.75442747615179
# Value of lambda: 0.82
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[-0.91, 6.75442747615179]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -1
# Additional constant: 1
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.6246212298263734
# Value of lambda: 0.07
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.11103480434035662y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -1.294242231501945
# Additional constant: 1.294242231501945
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.82
# Value of gamma: 0.7489593364149039
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[5.374983933313677, -0.6001373521873579]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 1.6500000000000004
# Additional constant: -1.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 8.7
# Value of lambda: 0.07
# Value of gamma: 9.1
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -3.6500000000000004
# Additional constant: 3.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 3.3000000000000003
# Value of lambda: 0.82
# Value of gamma: 5.1
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[-0.91, -4.399999999999999]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + 13.423400888500824y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 34.57201235452719
# Additional constant: -34.57201235452719
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 2.2
# Value of lambda: 0.07
# Value of gamma: 8.7
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.3518781065793195y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -1.9324769824351968
# Additional constant: 1.9324769824351968
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 8.5
# Value of lambda: 0.82
# Value of gamma: 2.8000000000000003
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[3.6722217864842097, -26.707137456934824]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -0.8500000000000005
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -2.8
# Additional constant: 2.8
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.73
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 0.7999999999999998
# Additional constant: -0.7999999999999998
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.64
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -9.134549999999997
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: 1.6500000000000004
# Additional constant: -1.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 8.7
# Value of lambda: 0.07
# Value of gamma: 9.1
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# Evaluation value: -3.6500000000000004
# Additional constant: 3.6500000000000004
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 3.3000000000000003
# Value of lambda: 0.82
# Value of gamma: 5.1
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 1.7999999999999998, "y" => 2.6500000000000004)
# ------------------------------
# _
#
# Num[-0.91, -4.399999999999999]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Finilizado el experimento completo
