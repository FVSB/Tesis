# %% [markdown]
# ## Importar el módulo

# %%
include("../../new_experiment.jl")
# Out:
# RunExperiment

# %%
using Random

# Random seed
Random.seed!(13)

# %% [markdown]
# Crear un experimento

# %%
experiment=CreateExperiment()
# Out:
# Experiment(OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[1], false), OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[], true), Any[], Any[])

# %% [markdown]
# ### Declarar variables del líder

# %%
@leader_vars experiment x_1,x_2
# Out:
# 2-element Vector{Num}:
#  x_1
#  x_2

# %% [markdown]
# ### Declarar Variables del Follower

# %%
@follower_vars experiment y_1,y_2
# Out:
# 2-element Vector{Num}:
#  y_1
#  y_2

# %% [markdown]
# ### Declarar Función Objetivo del Líder

# %%
SetLeaderFunction(experiment,2x_1+2x_2-3y_1-3y_2-60)
# Out:
# -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2

# %% [markdown]
# Restricciones del Líder

# %%
SetLeaderRestriction(experiment,x_1+x_2+y_1-2y_2-40<=0)
# Out:
# 1-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-40 + x_1 + x_2 + y_1 - 2y_2) <= 0, 0.86, J_0_g)

# %% [markdown]
# ### Función objetivo del Follower

# %%
SetFollowerFunction(experiment,(y_1-x_1+20)^2+(y_2-x_2+20)^2)
# Out:
# (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2

# %% [markdown]
# ### Restricciones del Follower

# %%
SetFollowerRestriction(experiment,-x_1+2y_2<=-10)
# Out:
# 1-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-x_1 + 2y_2) <= -10, J_0_LP_v, 0.49, 0.32, 0.24)

# %%
SetFollowerRestriction(experiment,-x_2+2y_2<=-10)
# Out:
# 2-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-x_1 + 2y_2) <= -10, J_0_LP_v, 0.49, 0.32, 0.24)
#  FollowerRestrictionProblem((-x_2 + 2y_2) <= -10, J_0_LP_v, 0.9, 0.82, 0.75)

# %%
SetFollowerRestriction(experiment,-y_1<=10)
# Out:
# 3-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-x_1 + 2y_2) <= -10, J_0_LP_v, 0.49, 0.32, 0.24)
#  FollowerRestrictionProblem((-x_2 + 2y_2) <= -10, J_0_LP_v, 0.9, 0.82, 0.75)
#  FollowerRestrictionProblem((-y_1) <= 10, J_0_LP_v, 0.49, 0.26, 0.02)

# %%
SetFollowerRestriction(experiment,y_1<=20)
# Out:
# 4-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-x_1 + 2y_2) <= -10, J_0_LP_v, 0.49, 0.32, 0.24)
#  FollowerRestrictionProblem((-x_2 + 2y_2) <= -10, J_0_LP_v, 0.9, 0.82, 0.75)
#  FollowerRestrictionProblem((-y_1) <= 10, J_0_LP_v, 0.49, 0.26, 0.02)
#  FollowerRestrictionProblem(y_1 <= 20, J_0_LP_v, 0.95, 0.85, 0.26)

# %%
SetFollowerRestriction(experiment,-y_2<=10)
# Out:
# 5-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-x_1 + 2y_2) <= -10, J_0_LP_v, 0.49, 0.32, 0.24)
#  FollowerRestrictionProblem((-x_2 + 2y_2) <= -10, J_0_LP_v, 0.9, 0.82, 0.75)
#  FollowerRestrictionProblem((-y_1) <= 10, J_0_LP_v, 0.49, 0.26, 0.02)
#  FollowerRestrictionProblem(y_1 <= 20, J_0_LP_v, 0.95, 0.85, 0.26)
#  FollowerRestrictionProblem((-y_2) <= 10, J_0_LP_v, 0.52, 0.7, 0.05)

# %%
SetFollowerRestriction(experiment,y_2<=20)
# Out:
# 6-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-x_1 + 2y_2) <= -10, J_0_LP_v, 0.49, 0.32, 0.24)
#  FollowerRestrictionProblem((-x_2 + 2y_2) <= -10, J_0_LP_v, 0.9, 0.82, 0.75)
#  FollowerRestrictionProblem((-y_1) <= 10, J_0_LP_v, 0.49, 0.26, 0.02)
#  FollowerRestrictionProblem(y_1 <= 20, J_0_LP_v, 0.95, 0.85, 0.26)
#  FollowerRestrictionProblem((-y_2) <= 10, J_0_LP_v, 0.52, 0.7, 0.05)
#  FollowerRestrictionProblem(y_2 <= 20, J_0_LP_v, 0.91, 0.51, 0.66)

# %% [markdown]
# ### Poner el Punto Optimo

# %%
SetPoint(experiment,Dict(x_1=>0,x_2=>0,y_1=>-10,y_2=>-10))
# Out:
# Dict{Any, Any} with 4 entries:
#   x_1 => 1.55
#   x_2 => 2.7
#   y_1 => -5.1
#   y_2 => -8.65

# %% [markdown]
# ## Iniciar el Experimento

# %%
RunExperiment(experiment,"ex9.2.3(Quadratic)",true)
# Out:
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: 15.991151188730084 - x_1 - 0.47749509053330513y_1 + 1.9510261445606867y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -5.991151188730084
# Additional constant: 5.991151188730084
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.49
# Value of lambda: 0.32
# Value of gamma: 0.24
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 17.141151188730085 - x_2 - 0.47749509053330513y_1 + 1.9510261445606867y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -7.141151188730083
# Additional constant: 7.141151188730083
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.9
# Value of lambda: 0.82
# Value of gamma: 0.75
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: 8.836887954940842 + 1.3277885663498625y_1 + 0.23874754526665257y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -18.836887954940842
# Additional constant: 18.836887954940842
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.49
# Value of lambda: 0.26
# Value of gamma: 0.02
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: -8.836887954940844 - 1.3277885663498625y_1 - 0.23874754526665257y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -11.163112045059156
# Additional constant: 11.163112045059156
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.95
# Value of lambda: 0.85
# Value of gamma: 0.26
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -7.220575594365041 + 0.23874754526665257y_1 - 0.9755130722803433y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -2.779424405634959
# Additional constant: 2.779424405634959
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.52
# Value of lambda: 0.7
# Value of gamma: 0.05
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: 7.2205755943650445 - 0.23874754526665257y_1 + 0.9755130722803433y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -27.220575594365044
# Additional constant: 27.220575594365044
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.91
# Value of lambda: 0.51
# Value of gamma: 0.66
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[2.3099999999999996, -1.48, -1.1723875409837743, 1.2574474316939717]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: 18.85 - x_1 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -8.850000000000001
# Additional constant: 8.850000000000001
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.32
# Value of gamma: 8.9
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 20.0 - x_2 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.0
# Additional constant: 10.0
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.82
# Value of gamma: 6.4
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: -5.1 - y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -4.9
# Additional constant: 4.9
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -2.9
# Value of lambda: 0.26
# Value of gamma: -8.6
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: 5.100000000000001 + y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -25.1
# Additional constant: 25.1
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.85
# Value of gamma: 1.9
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -11.35 - y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -1.3499999999999996
# Additional constant: -1.3499999999999996
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.7
# Value of gamma: 5.6000000000000005
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: -48.65 + y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -28.65
# Additional constant: -28.65
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 7.9
# Value of lambda: 0.51
# Value of gamma: 1.5
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[-2.86, -2.86, -0.7599999999999998, -3.1800000000000006]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# Carpeta creada: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: -18.852633622820022 - x_1 - 1.383887594436207y_1 - 1.54275224175669y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 28.852633622820022
# Additional constant: -28.852633622820022
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -9.6
# Value of lambda: 0.32
# Value of gamma: -4.0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 1.5334039398432555 - x_2 - 0.6778224952340606y_1 + 0.2647744122008051y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 8.466596060156744
# Additional constant: -8.466596060156744
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.9000000000000004
# Value of lambda: 0.82
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: -1.4932429570006356 - 0.8676127938995976y_1 + 0.3389112476170303y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -8.506757042999364
# Additional constant: 8.506757042999364
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 1.4000000000000001
# Value of lambda: 0.26
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: -2.3345578210613525 + 0.7271121046446428y_1 - 0.6985930121097145y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -17.665442178938648
# Additional constant: 17.665442178938648
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: -2.7
# Value of lambda: 0.85
# Value of gamma: -9.7
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -40.78113747087482 + 1.0802796017792842y_1 + 1.765515780554967y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -30.781137470874818
# Additional constant: -30.781137470874818
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 9.3
# Value of lambda: 0.7
# Value of gamma: 4.2
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: -60.576343288851234 + 0.43776036150533093y_1 + 2.1206665254536468y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -40.576343288851234
# Additional constant: -40.576343288851234
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.51
# Value of gamma: 4.4
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[-10.959999999999999, 4.880000000000001, -16.87055287772212, -33.74301536696863]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: 18.85 - x_1 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -8.850000000000001
# Additional constant: 8.850000000000001
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.32
# Value of gamma: 8.9
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 20.0 - x_2 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.0
# Additional constant: 10.0
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.82
# Value of gamma: 6.4
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: -5.1 - y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -4.9
# Additional constant: 4.9
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -2.9
# Value of lambda: 0.26
# Value of gamma: -8.6
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: 5.100000000000001 + y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -25.1
# Additional constant: 25.1
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.85
# Value of gamma: 1.9
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -11.35 - y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -1.3499999999999996
# Additional constant: -1.3499999999999996
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.7
# Value of gamma: 5.6000000000000005
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: -48.65 + y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -28.65
# Additional constant: -28.65
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 7.9
# Value of lambda: 0.51
# Value of gamma: 1.5
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[-2.86, -2.86, -0.7599999999999998, -3.1800000000000006]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: 1.590713365173226 - x_1 - 2.0115988173754835y_1 + 1.1907361079523917y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 8.409286634826774
# Additional constant: -8.409286634826774
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -9.6
# Value of lambda: 0.32
# Value of gamma: -4.0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 14.058278371617012 - x_2 - 0.6925176256538549y_1 + 1.721400955196725y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -4.058278371617012
# Additional constant: 4.058278371617012
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.9000000000000004
# Value of lambda: 0.82
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: 2.2847111667045716 - 0.13929952240163745y_1 + 0.34625881282692744y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -12.284711166704572
# Additional constant: 12.284711166704572
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 1.4000000000000001
# Value of lambda: 0.26
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: -15.675333259066456 - 1.421399951153837y_1 - 0.9741264171308539y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -4.324666740933544
# Additional constant: 4.324666740933544
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: -2.7
# Value of lambda: 0.85
# Value of gamma: -9.7
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -26.204304070957473 + 1.7312940641346375y_1 - 0.3035023879918126y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -16.204304070957473
# Additional constant: -16.204304070957473
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 9.3
# Value of lambda: 0.7
# Value of gamma: 4.2
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: -58.128460692896674 + 1.1047304980668642y_1 + 1.4444318095671291y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -38.128460692896674
# Additional constant: -38.128460692896674
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.51
# Value of gamma: 4.4
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[-7.24, 3.14, -39.434325239959804, 7.045271455188585]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: 18.85 - x_1 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -8.850000000000001
# Additional constant: 8.850000000000001
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.32
# Value of gamma: 6.0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 20.0 - x_2 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.0
# Additional constant: 10.0
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 8.2
# Value of lambda: 0.82
# Value of gamma: 4.2
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: -5.1 - y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -4.9
# Additional constant: 4.9
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 2.7
# Value of lambda: 0.26
# Value of gamma: 5.0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: 5.100000000000001 + y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -25.1
# Additional constant: 25.1
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.7000000000000001
# Value of lambda: 0.85
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -11.35 - y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -1.3499999999999996
# Additional constant: -1.3499999999999996
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 2.5
# Value of lambda: 0.7
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: -48.65 + y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -28.65
# Additional constant: -28.65
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 5.5
# Value of lambda: 0.51
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[-2.86, 5.34, 4.140000000000001, -14.68]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: 20.12839819112222 - x_1 + 0.08539807211710101y_1 + 2.0974413899797693y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.12839819112222
# Additional constant: 10.12839819112222
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 6.8999999999999995
# Value of lambda: 0.32
# Value of gamma: 5.8
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 5.159464476972512 - x_2 - 0.991360228489825y_1 + 0.8688325598000715y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 4.840535523027488
# Additional constant: -4.840535523027488
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 9.7
# Value of lambda: 0.82
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: 24.469905985957396 + 0.9752945376651194y_1 + 2.25386171605379y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -34.469905985957396
# Additional constant: 34.469905985957396
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 5.6000000000000005
# Value of lambda: 0.26
# Value of gamma: 8.299999999999999
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: -17.988035658026536 - 0.5423001595735621y_1 - 1.7598040282313723y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -2.0119643419734636
# Additional constant: 2.0119643419734636
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 8.4
# Value of lambda: 0.85
# Value of gamma: 4.1
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -41.5591050815185 + 2.0179935737236696y_1 + 1.3025824110436748y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -31.559105081518503
# Additional constant: -31.559105081518503
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 9.9
# Value of lambda: 0.7
# Value of gamma: 8.2
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: -41.785557538974174 - 0.45855051767225985y_1 + 0.47678210163037016y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -21.785557538974174
# Additional constant: -21.785557538974174
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.51
# Value of gamma: 0.2
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[8.719999999999999, 12.18, -14.397516931627774, -34.254859063011175]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: 18.85 - x_1 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -8.850000000000001
# Additional constant: 8.850000000000001
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.32
# Value of gamma: 6.0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 20.0 - x_2 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.0
# Additional constant: 10.0
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 8.2
# Value of lambda: 0.82
# Value of gamma: 4.2
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: -5.1 - y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -4.9
# Additional constant: 4.9
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 2.7
# Value of lambda: 0.26
# Value of gamma: 5.0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: 5.100000000000001 + y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -25.1
# Additional constant: 25.1
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.7000000000000001
# Value of lambda: 0.85
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -11.35 - y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -1.3499999999999996
# Additional constant: -1.3499999999999996
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 2.5
# Value of lambda: 0.7
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: -48.65 + y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -28.65
# Additional constant: -28.65
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 5.5
# Value of lambda: 0.51
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[-2.86, 5.34, 4.140000000000001, -14.68]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: 36.33786244626807 - x_1 + 1.89980461117624y_1 + 2.901602188354826y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -26.33786244626807
# Additional constant: 26.33786244626807
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 6.8999999999999995
# Value of lambda: 0.32
# Value of gamma: 5.8
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 12.86902696365768 - x_2 - 0.7746776084407971y_1 + 1.632356389214537y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -2.8690269636576797
# Additional constant: 2.8690269636576797
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 9.7
# Value of lambda: 0.82
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: 37.643391949980455 + 3.643454474404063y_1 + 2.2036733098866743y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -47.643391949980455
# Additional constant: 47.643391949980455
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 5.6000000000000005
# Value of lambda: 0.26
# Value of gamma: 8.299999999999999
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: -9.619516726235522 - 0.5990636841242787y_1 - 0.7588776806013526y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.380483273764478
# Additional constant: 10.380483273764478
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 8.4
# Value of lambda: 0.85
# Value of gamma: 4.1
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -49.72142633841344 + 4.168503321610003y_1 + 0.9782727627979677y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -39.72142633841344
# Additional constant: -39.72142633841344
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 9.9
# Value of lambda: 0.7
# Value of gamma: 8.2
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: -45.93343884329816 - 0.29511527940601795y_1 + 0.8599452911293474y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -25.933438843298163
# Additional constant: -25.933438843298163
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.51
# Value of gamma: 0.2
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[7.58, 8.52, -63.633672009198165, -48.465810445043196]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: 18.85 - x_1 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -8.850000000000001
# Additional constant: 8.850000000000001
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.5999999999999996
# Value of lambda: 0.32
# Value of gamma: 7.7
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 20.0 - x_2 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.0
# Additional constant: 10.0
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 4.3
# Value of lambda: 0.82
# Value of gamma: 0.4
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: -5.1 - y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -4.9
# Additional constant: 4.9
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 7.800000000000001
# Value of lambda: 0.26
# Value of gamma: 4.2
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: 5.100000000000001 + y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -25.1
# Additional constant: 25.1
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 1.9
# Value of lambda: 0.85
# Value of gamma: 0.3
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -11.35 - y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -1.3499999999999996
# Additional constant: -1.3499999999999996
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 6.1
# Value of lambda: 0.7
# Value of gamma: 5.8999999999999995
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: -48.65 + y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -28.65
# Additional constant: -28.65
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 1.5
# Value of lambda: 0.51
# Value of gamma: 8.5
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[0.7399999999999998, 1.44, 8.040000000000001, -6.4799999999999995]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: 18.96236363636364 - x_1 + 0.009696969696969704y_1 + 2.0072727272727273y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -8.962363636363639
# Additional constant: 8.962363636363639
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 6.8999999999999995
# Value of lambda: 0.32
# Value of gamma: 4.0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 13.089636363636366 - x_2 - 0.5963636363636362y_1 + 1.5527272727272727y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -3.089636363636366
# Additional constant: 3.089636363636366
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.5999999999999996
# Value of lambda: 0.82
# Value of gamma: 1.5
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: 19.73236363636363 + 1.1430303030303026y_1 + 1.607272727272727y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -29.73236363636363
# Additional constant: 29.73236363636363
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0.6
# Value of lambda: 0.26
# Value of gamma: 6.2
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: -19.372799999999998 - 1.112y_1 - 1.5839999999999999y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -0.627200000000002
# Additional constant: 0.627200000000002
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 3.9000000000000004
# Value of lambda: 0.85
# Value of gamma: 5.6000000000000005
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -37.13745454545454 + 2.2254545454545447y_1 + 0.6690909090909085y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -27.13745454545454
# Additional constant: -27.13745454545454
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 8.6
# Value of lambda: 0.7
# Value of gamma: 7.199999999999999
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: -56.29072727272727 + 0.6593939393939391y_1 + 1.4945454545454542y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -36.29072727272727
# Additional constant: -36.29072727272727
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 1.6
# Value of lambda: 0.51
# Value of gamma: 4.699999999999999
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[9.32, 4.699999999999999, -17.602957575757568, -21.61221818181818]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Parsed expression: -60 + 2x_1 + 2x_2 - 3y_1 - 3y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.25
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (-40 + x_1 + x_2 + y_1 - 2y_2) == 0
# Parsed expression: -16.45 + x_1 + x_2 + y_1 - 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -23.55
# Additional constant: 23.55
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.86
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:x_1, :y_1, :x_2, :y_2]
# Expression (string): (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Parsed expression: (20 - x_1 + y_1)^2 + (20 - x_2 + y_2)^2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: 253.04500000000002
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x_1, :y_2]
# Expression (string): (-x_1 + 2y_2) == -10
# Parsed expression: 18.85 - x_1 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -8.850000000000001
# Additional constant: 8.850000000000001
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 3.5999999999999996
# Value of lambda: 0.32
# Value of gamma: 7.7
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x_2, :y_2]
# Expression (string): (-x_2 + 2y_2) == -10
# Parsed expression: 20.0 - x_2 + 2y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -10.0
# Additional constant: 10.0
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 4.3
# Value of lambda: 0.82
# Value of gamma: 0.4
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 3
# Variable names: [:y_1]
# Expression (string): (-y_1) == 10
# Parsed expression: -5.1 - y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -4.9
# Additional constant: 4.9
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 7.800000000000001
# Value of lambda: 0.26
# Value of gamma: 4.2
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 4
# Variable names: [:y_1]
# Expression (string): y_1 == 20
# Parsed expression: 5.100000000000001 + y_1
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -25.1
# Additional constant: 25.1
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 1.9
# Value of lambda: 0.85
# Value of gamma: 0.3
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 5
# Variable names: [:y_2]
# Expression (string): (-y_2) == 10
# Parsed expression: -11.35 - y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -1.3499999999999996
# Additional constant: -1.3499999999999996
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 6.1
# Value of lambda: 0.7
# Value of gamma: 5.8999999999999995
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 6
# Variable names: [:y_2]
# Expression (string): y_2 == 20
# Parsed expression: -48.65 + y_2
# Evaluation point: Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# Evaluation value: -28.65
# Additional constant: -28.65
# Restriction type: LtEq
# Restriction set type: J_Ne_L0_v
# Value of miu: 0
# Value of beta: 1.5
# Value of lambda: 0.51
# Value of gamma: 8.5
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x_1" => 1.55, "x_2" => 2.7, "y_2" => -8.65, "y_1" => -5.1)
# ------------------------------
# _
#
# Num[0.7399999999999998, 1.44, 8.040000000000001, -6.4799999999999995]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\quadratic\ex9.2.3\Experimentos_Generador
# Experimento Completado
# Finilizado el experimento completo
