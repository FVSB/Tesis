# %% [markdown]
# ## Importar el módulo

# %%
include("../../new_experiment.jl")
# Out:
# RunExperiment

# %% [markdown]
# Crear un experimento

# %%
experiment=CreateExperiment()
# Out:
# Experiment(OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[1], false), OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[], true), Any[], Any[])

# %% [markdown]
# ### Declarar variables del líder

# %%
@leader_vars experiment x
# Out:
# 1-element Vector{Num}:
#  x

# %% [markdown]
# ### Declarar Variables del Follower

# %%
@follower_vars experiment y
# Out:
# 1-element Vector{Num}:
#  y

# %% [markdown]
# ### Declarar Función Objetivo del Líder

# %%
SetLeaderFunction(experiment,x-y)
# Out:
# x - y

# %% [markdown]
# Restricciones del Líder

# %%
SetLeaderRestriction(experiment,-x-1<=0)
# Out:
# 1-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 - x) <= 0, 0.10379143254523569, J_0_g)

# %%
SetLeaderRestriction(experiment,x-1<=0)
# Out:
# 2-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 - x) <= 0, 0.10379143254523569, J_0_g)
#  LeaderRestrictionProblem((-1 + x) <= 0, 0.5815339895515225, J_0_g)

# %% [markdown]
# ### Función objetivo del Follower

# %%
SetFollowerFunction(experiment,(0.5x*(y^2))-((x^3)*y))
# Out:
# 0.5x*(y^2) - (x^3)*y

# %% [markdown]
# ### Restricciones del Follower

# %%
SetFollowerRestriction(experiment,y-1<=0)
# Out:
# 1-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.027153788226891844, 0.07674479715761028, 0.9395353761532388)

# %%
SetFollowerRestriction(experiment,-y-1<=0)
# Out:
# 2-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.027153788226891844, 0.07674479715761028, 0.9395353761532388)
#  FollowerRestrictionProblem((-1 - y) <= 0, J_0_LP_v, 0.855784099003775, 0.3039754280005046, 0.34823670119787486)

# %% [markdown]
# ### Poner el Punto Optimo

# %%
SetPoint(experiment,Dict(x=>0,y=>1))
# Out:
# Dict{Any, Any} with 2 entries:
#   y => 1.54403
#   x => 0.852232

# %% [markdown]
# ## Iniciar el Experimento

# %%
RunExperiment(experiment,"MitsosBarton2006Ex313",true)
# Out:
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + 0.1791858540480532y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.7233322398627675
# Additional constant: 0.7233322398627675
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.027153788226891844
# Value of lambda: 0.07674479715761028
# Value of gamma: 0.9395353761532388
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.1791858540480532y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.2766677601372325
# Additional constant: 1.2766677601372325
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.855784099003775
# Value of lambda: 0.3039754280005046
# Value of gamma: 0.34823670119787486
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-0.9566309139610452, 0.4489546981120749]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.5440267961277625
# Additional constant: -0.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0.6304842008663022
# Value of lambda: 0.07674479715761028
# Value of gamma: 0.4956384162386672
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -2.5440267961277625
# Additional constant: 2.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.7478293440119714
# Value of lambda: 0.3039754280005046
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-1.4777425570062868, 1.1173451431456694]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# Carpeta creada: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 - 0.19730649554907154y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.3046465161778296
# Additional constant: 1.3046465161778296
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -0.7563408495808517
# Value of lambda: 0.07674479715761028
# Value of gamma: -0.10901335003570511
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.44749234062295395y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.690940164983773
# Additional constant: 1.690940164983773
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.6472896929601298
# Value of lambda: 0.3039754280005046
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-1.1269710996757878, 0.6695614756786108]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.5440267961277625
# Additional constant: -0.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0.6304842008663022
# Value of lambda: 0.07674479715761028
# Value of gamma: 0.4956384162386672
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -2.5440267961277625
# Additional constant: 2.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.7478293440119714
# Value of lambda: 0.3039754280005046
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-1.4777425570062868, 1.1173451431456694]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 - 0.16295675763467488y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.2516096003980355
# Additional constant: 1.2516096003980355
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -0.7563408495808517
# Value of lambda: 0.07674479715761028
# Value of gamma: -0.10901335003570511
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.3310289697829102y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.5111175996393809
# Additional constant: 1.5111175996393809
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.6472896929601298
# Value of lambda: 0.3039754280005046
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-1.0530318055830232, 0.520902227448847]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.5440267961277625
# Additional constant: -0.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.07674479715761028
# Value of gamma: 0.44648049417590874
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -2.5440267961277625
# Additional constant: 2.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.012866611463594801
# Value of lambda: 0.3039754280005046
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-1.4777425570062868, 1.0128666114635947]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + 0.39189262644951195y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.39490728355706606
# Additional constant: 0.39490728355706606
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.07674479715761028
# Value of gamma: 0.14721800080787562
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.6243409779315102y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.9639991998468638
# Additional constant: 1.9639991998468638
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.3039754280005046
# Value of gamma: 0.40345789262779175
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-1.2392472883997199, 0.6798513371550003]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.5440267961277625
# Additional constant: -0.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.07674479715761028
# Value of gamma: 0.44648049417590874
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -2.5440267961277625
# Additional constant: 2.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.012866611463594801
# Value of lambda: 0.3039754280005046
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-1.4777425570062868, 1.0128666114635947]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + 0.24838927909415343y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6164802972077696
# Additional constant: 0.6164802972077696
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.07674479715761028
# Value of gamma: 0.14721800080787562
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.4073093599499853y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.6288965660764254
# Additional constant: 1.6288965660764254
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.3039754280005046
# Value of gamma: 0.40345789262779175
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-1.1014600638533476, 0.49489003392506203]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.5440267961277625
# Additional constant: -0.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0.3627849386082045
# Value of lambda: 0.07674479715761028
# Value of gamma: 0.09862201868160002
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -2.5440267961277625
# Additional constant: 2.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.9310240118667771
# Value of lambda: 0.3039754280005046
# Value of gamma: 0.5961540305870568
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-1.4777425570062868, 1.5682390732585727]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + 0.5008264278971426y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.22671057511786308
# Additional constant: 0.22671057511786308
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0.26061391327685735
# Value of lambda: 0.07674479715761028
# Value of gamma: 0.3394748891400814
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.32217057601081467y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.497440002284614
# Additional constant: 1.497440002284614
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.6042329526598001
# Value of lambda: 0.3039754280005046
# Value of gamma: 0.10221880124077497
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-1.0474078623845726, 0.48647577572082057]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): x - y
# Parsed expression: x - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.6917947345039889
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -1.8522320616237735
# Additional constant: 1.8522320616237735
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.10379143254523569
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -0.14776793837622637
# Additional constant: 0.14776793837622637
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.5815339895515225
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): 0.5x*(y^2) - (x^3)*y
# Parsed expression: 0.5x*(y^2) - (x^3)*y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.06015352500728155
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: 0.5440267961277625
# Additional constant: -0.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0.3627849386082045
# Value of lambda: 0.07674479715761028
# Value of gamma: 0.09862201868160002
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# Evaluation value: -2.5440267961277625
# Additional constant: 2.5440267961277625
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.9310240118667771
# Value of lambda: 0.3039754280005046
# Value of gamma: 0.5961540305870568
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.8522320616237736, "y" => 1.5440267961277625)
# ------------------------------
# _
#
# Num[-1.4777425570062868, 1.5682390732585727]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex313\Experimentos_Generador
# Experimento Completado
# Finilizado el experimento completo
