# %% [markdown]
# ## Importar el módulo

# %%
include("../../new_experiment.jl")
# Out:
# RunExperiment

# %% [markdown]
# Crear un experimento

# %%
experiment=CreateExperiment()
# Out:
# Experiment(OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[1], false), OptimizationModel(Problem(Any[], nothing), LeaderRestrictionProblem[], Problem(Any[], nothing), FollowerRestrictionProblem[], Dict{Any, Any}(), Number[], true), Any[], Any[])

# %% [markdown]
# ### Declarar variables del líder

# %%
@leader_vars experiment x
# Out:
# 1-element Vector{Num}:
#  x

# %% [markdown]
# ### Declarar Variables del Follower

# %%
@follower_vars experiment y
# Out:
# 1-element Vector{Num}:
#  y

# %% [markdown]
# ### Declarar Función Objetivo del Líder

# %%
SetLeaderFunction(experiment,((x-0.25)^2)+(y^2))
# Out:
# (-0.25 + x)^2 + y^2

# %% [markdown]
# Restricciones del Líder

# %%
SetLeaderRestriction(experiment,x-1<=0)
# Out:
# 1-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 + x) <= 0, 0.1869798624383242, J_0_g)

# %%
SetLeaderRestriction(experiment,-x-1<=0)
# Out:
# 2-element Vector{LeaderRestrictionProblem}:
#  LeaderRestrictionProblem((-1 + x) <= 0, 0.1869798624383242, J_0_g)
#  LeaderRestrictionProblem((-1 - x) <= 0, 0.3307618713826723, J_0_g)

# %% [markdown]
# ### Función objetivo del Follower

# %%
SetFollowerFunction(experiment,((1/3)*(y^3))-(x*y))
# Out:
# -x*y + 0.3333333333333333(y^3)

# %% [markdown]
# ### Restricciones del Follower

# %%
SetFollowerRestriction(experiment,y-1<=0)
# Out:
# 1-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.006256741556184045, 0.4716596798672763, 0.8628758773724446)

# %%
SetFollowerRestriction(experiment,-y-1<=0)
# Out:
# 2-element Vector{FollowerRestrictionProblem}:
#  FollowerRestrictionProblem((-1 + y) <= 0, J_0_LP_v, 0.006256741556184045, 0.4716596798672763, 0.8628758773724446)
#  FollowerRestrictionProblem((-1 - y) <= 0, J_0_LP_v, 0.1491036474617422, 0.9232357192894672, 0.8992454476553271)

# %% [markdown]
# ### Poner el Punto Optimo

# %%
SetPoint(experiment,Dict(x=>0.25,y=>0.5))
# Out:
# Dict{Any, Any} with 2 entries:
#   y => 0.793559
#   x => 0.549326

# %% [markdown]
# ## Iniciar el Experimento

# %%
RunExperiment(experiment,"MitsosBarton2006Ex314",true)
# Out:
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: 0.7193319751289964
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -0.4506741868524874
# Additional constant: 0.4506741868524874
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.1869798624383242
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -1.5493258131475125
# Additional constant: 1.5493258131475125
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.3307618713826723
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -0.269344908766822
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + 0.8692714417465267y
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -0.31018174386740116
# Additional constant: 0.31018174386740116
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.006256741556184045
# Value of lambda: 0.4716596798672763
# Value of gamma: 0.8628758773724446
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.8692714417465267y
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -1.689818256132599
# Additional constant: 1.689818256132599
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.1491036474617422
# Value of lambda: 0.9232357192894672
# Value of gamma: 0.8992454476553271
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# ------------------------------
# _
#
# Num[-0.3241410590972038, -1.6704271204354253]
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: 0.7193319751289964
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -0.4506741868524874
# Additional constant: 0.4506741868524874
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.1869798624383242
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -1.5493258131475125
# Additional constant: 1.5493258131475125
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.3307618713826723
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -0.269344908766822
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 + y
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -0.20644090786345548
# Additional constant: 0.20644090786345548
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: 0.24284065935533405
# Value of lambda: 0.4716596798672763
# Value of gamma: 0.7868907310280077
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - y
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -1.7935590921365445
# Additional constant: 1.7935590921365445
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0
# Value of lambda: 0.9232357192894672
# Value of gamma: 0.2940421676375965
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# ------------------------------
# _
#
# Num[-0.4548696173506771, -1.829958843628423]
# Se va a crear el DataFrame
# Se va a crear el DataFrame
# Carpeta creada: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Se va a crear el DataFrame
# La carpeta ya existe: d:\GitHub\Tesis\experiment\nonconvex\MitsosBarton2006Ex314\Experimentos_Generador
# Experimento Completado
# Va a retornar correctamente
# Leader's Objective Function:
# Variable names: [:y, :x]
# Expression (string): (-0.25 + x)^2 + y^2
# Parsed expression: (-0.25 + x)^2 + y^2
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: 0.7193319751289964
# Is leader function: true
# ------------------------------
# Leader's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:x]
# Expression (string): (-1 + x) == 0
# Parsed expression: -1 + x
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -0.4506741868524874
# Additional constant: 0.4506741868524874
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.1869798624383242
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:x]
# Expression (string): (-1 - x) == 0
# Parsed expression: -1 - x
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -1.5493258131475125
# Additional constant: 1.5493258131475125
# Restriction type: LtEq
# Restriction set type: J_0_g
# Value of miu: 0.3307618713826723
# Value of beta: 0
# Value of lambda: 0
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Follower's Objective Function:
# Variable names: [:y, :x]
# Expression (string): -x*y + 0.3333333333333333(y^3)
# Parsed expression: -x*y + 0.3333333333333333(y^3)
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -0.269344908766822
# Is leader function: false
# ------------------------------
# Follower's Restrictions:
# ++++++++++++++++++++++++++++++
# Restriction 1
# Variable names: [:y]
# Expression (string): (-1 + y) == 0
# Parsed expression: -1 - 2.215361109663986y
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -2.758019950939561
# Additional constant: 2.758019950939561
# Restriction type: LtEq
# Restriction set type: J_0_L0_v
# Value of miu: 0
# Value of beta: -0.6451576973310351
# Value of lambda: 0.4716596798672763
# Value of gamma: -0.812745084829267
# ++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++
# Restriction 2
# Variable names: [:y]
# Expression (string): (-1 - y) == 0
# Parsed expression: -1 - 0.6331320066584811y
# Evaluation point: Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# Evaluation value: -1.502427660406493
# Additional constant: 1.502427660406493
# Restriction type: LtEq
# Restriction set type: J_0_LP_v
# Value of miu: 0
# Value of beta: 0.11089915863658728
# Value of lambda: 0.9232357192894672
# Value of gamma: 0
# ++++++++++++++++++++++++++++++
# ------------------------------
# Evaluation Point:
# Dict{Any, Any}("x" => 0.5493258131475126, "y" => 0.7935590921365445)
# ------------------------------
# _
#
# Num[-0