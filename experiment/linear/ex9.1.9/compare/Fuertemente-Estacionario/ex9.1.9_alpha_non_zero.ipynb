# %% [markdown]
# # Importar las depencias necesarias

# %%
include("../../../../experiment.jl")

# %%
using BilevelJuMP

# %%
model=BilevelModel()
# Out:
# An Abstract JuMP Model
# Feasibility problem with:
# Variables: 0
# Upper Constraints: 0
# Lower Constraints: 0
# Bilevel Model
# Solution method: BilevelJuMP.NoMode{Float64}
# No solver attached

# %% [markdown]
# ## Definir variables

# %%
BilevelJuMP.@variable(Upper(model),0<=x)
BilevelJuMP.@variable(Lower(model),0<=y)
# Out:
# y

# %% [markdown]
# ## Definir nivel superior

# %%
BilevelJuMP.@objective(Upper(model),Min,x+y)
# Out:
# x + y

# %% [markdown]
# ## Definir Nivel inferior

# %%
BilevelJuMP.@objective(Lower(model),Min,-5x-y)
BilevelJuMP.@constraints(Lower(model),begin
c1,2 - x + 0.8565037622097824y<=-0
c2,-2 - 0.25x + 0.672956621844949y<=0
c3,-8 + x + 0.030487450054021092y<=0
c4,-2 + x + 1.0193433106225216y<=0
c5,0.575015938750449y<=0

end)
# Out:
# (c1 : -x + 0.8565037622097824 y ≤ -2, c2 : -0.25 x + 0.672956621844949 y ≤ 2, c3 : x + 0.030487450054021092 y ≤ 8, c4 : x + 1.0193433106225216 y ≤ 2, c5 : 0.575015938750449 y ≤ 0)

# %% [markdown]
# ## Run

# %%
start_experiment(model,[x],[y],"ex9.1.9(Linear)_alpha_non_zero")
# Out:
# Resolviendo el problema con HiGHS
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [3e-02, 1e+02]
#   Cost   [1e+00, 1e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           1 from [lower, value, upper] = [             -1;               0;              -1]
# WARNING: Row      3 has         infeasibility of           8 from [lower, value, upper] = [              8;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      5            8           15
# Row     residuals            0            0            0
# ...
