# %% [markdown]
# # Importar las depencias necesarias

# %%
include("../../../../experiment.jl")

# %%
using BilevelJuMP

# %%
model=BilevelModel()
# Out:
# An Abstract JuMP Model
# Feasibility problem with:
# Variables: 0
# Upper Constraints: 0
# Lower Constraints: 0
# Bilevel Model
# Solution method: BilevelJuMP.NoMode{Float64}
# No solver attached

# %% [markdown]
# ## Definir variables

# %%
BilevelJuMP.@variable(Upper(model),0<=x[1:2])
BilevelJuMP.@variable(Lower(model),0<=y[1:2])
# Out:
# 2-element Vector{BilevelVariableRef}:
#  y[1]
#  y[2]

# %% [markdown]
# ## Definir nivel superior

# %%
BilevelJuMP.@objective(Upper(model),Min,-2x[1]+x[2]+0.5y[1])
# Out:
# -2 x[1] + x[2] + 0.5 y[1]

# %% [markdown]
# ## Definir Nivel inferior

# %%
BilevelJuMP.@objective(Lower(model),Min,-4y[1]+y[2]+x[1]+x[2])
BilevelJuMP.@constraints(Lower(model),begin
c1,-129.58 - 2x[1] + 2.2y[1] + 1.58y[2]<=0
c2,48.36 + x[1] - 3x[2] - 0.38y[1] + 0.18y[2]<=0
c3,45.07 - 0.45y[1] + 1.17y[2]<=0
c4,-39.81 + 0.39y[1] - 0.18y[2]<=0
end)
# Out:
# (c1 : -2 x[1] + 2.2 y[1] + 1.58 y[2] ≤ 129.58, c2 : x[1] - 3 x[2] - 0.38 y[1] + 0.18 y[2] ≤ -48.36, c3 : -0.45 y[1] + 1.17 y[2] ≤ -45.07, c4 : 0.39 y[1] - 0.18 y[2] ≤ 39.81)

# %% [markdown]
# ## Run

# %%
start_experiment(model,x,y,"ex9.1.10(Linear)_alpha_non_zero")
# Out:
# Resolviendo el problema con HiGHS
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [7e-02, 3e+02]
#   Cost   [5e-01, 2e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           4 from [lower, value, upper] = [             -4;               0;              -4]
# WARNING: Row      6 has         infeasibility of       129.6 from [lower, value, upper] = [         129.58;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      6        129.6        267.8
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [7e-02, 3e+02]
#   Cost   [5e-01, 2e+00]
#   Bound  [0e+00, 0e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# Presolve: Infeasible
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -inf            inf                  inf        0    -18      0         0     0.0s
#
# Solving report
#   Status            Infeasible
#   Primal bound      inf
#   Dual bound        -inf
#   Gap               inf
#   P-D integral      0
#   Solution status   -
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             0
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     0 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Solving LP to try to compute dual ray
# Coefficient ranges:
#   Matrix [7e-02, 3e+02]
#   Cost   [0e+00, 0e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+02]
# Solving LP relaxation since solve_relaxation is true
# Solving LP without presolve, or with basis, or unconstrained
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0     0.0000000000e+00 Pr: 6(768.34) 0s
#           7     7.1056696435e-04 0s
# Model status        : Infeasible
# Simplex   iterations: 7
# Objective value     :  0.0000000000e+00
# Relative P-D gap    :  7.1056696435e-04
# HiGHS run time      :          0.00
# Solving linear system to compute dual ray
# optimize Method: Highs-BigM (100,100)
# Primal Status: NO_SOLUTION
# Termination Status: INFEASIBLE
# Objetive Value 0.0
# Lider Vars: [2.5e-323, 2.5e-323]
# Followers Vars Value [3.0e-323, 2.5e-323]
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [7e-02, 3e+02]
#   Cost   [5e-01, 2e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+02]
# Assessing feasibility of MIP using primal feasibility and integrality tolerance of       1e-06
# WARNING: Row      0 has         infeasibility of           4 from [lower, value, upper] = [             -4;               0;              -4]
# WARNING: Row      6 has         infeasibility of       129.6 from [lower, value, upper] = [         129.58;               0;             inf]
# Solution has               num          max          sum
# Col     infeasibilities      0            0            0
# Integer infeasibilities      0            0            0
# Row     infeasibilities      6        129.6        267.8
# Row     residuals            0            0            0
# Attempting to find feasible solution by solving LP for user-supplied values of discrete variables
# Coefficient ranges:
#   Matrix [7e-02, 3e+02]
#   Cost   [5e-01, 2e+00]
#   Bound  [0e+00, 0e+00]
#   RHS    [1e+00, 1e+02]
# Presolving model
# Problem status detected on presolve: Infeasible
# Model status        : Infeasible
# Objective value     :  0.0000000000e+00
# HiGHS run time      :          0.00
# Presolving model
# Presolve: Infeasible
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   -inf            inf                  inf        0    -18      0         0     0.0s
#
# Solving report
#   Status            Infeasible
#   Primal bound      inf
#   Dual bound        -inf
#   Gap               inf
#   P-D integral      0
#   Solution status   -
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             0
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     0 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# Solving LP to try to compute dual ray
# Coefficient ranges:
#   Matrix [7e-02, 3e+02]
#   Cost   [0e+00, 0e+00]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 1e+02]
# Solving LP relaxation since solve_relaxation is true
# Solving LP without presolve, or with basis, or unconstrained
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0     0.0000000000e+00 Pr: 6(768.34) 0s
#           7     7.1056696435e-04 0s
# Model status        : Infeasible
# Simplex   iterations: 7
# Objective value     :  0.0000000000e+00
# Relative P-D gap    :  7.1056696435e-04
# HiGHS run time      :          0.00
# Solving linear system to compute dual ray
# Running HiGHS 1.9.0 (git hash: 66f735e60): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix
#   65 -2.4928975e+01 4.20e-06 6.08e+02  -5.7 1.21e+01    -  6.38e-02 1.00e+00f  1
#   66 -2.4928975e+01 4.44e-16 5.06e-04  -5.7 1.15e-05  -0.2 1.00e+00 1.00e+00h  1
#   67 -2.4928975e+01 3.11e-15 1.94e+02  -5.7 1.78e+01    -  7.05e-01 1.00e+00f  1
#   68 -2.4928975e+01 3.22e-05 8.98e+02  -5.7 9.28e+01    -  4.69e-01 1.00e+00h  1
#   69 -2.4928975e+01 7.11e-15 3.08e-06  -5.7 1.35e-05  -0.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70 -2.4928975e+01 7.11e-15 4.35e+01  -8.6 1.92e-01    -  8.81e-01 1.00e+00h  1
# In iteration 70, 1 Slack too small, adjusting variable bound
#   71 -2.4928976e+01 1.11e-15 1.44e+01  -8.6 1.80e+01    -  6.87e-01 8.66e-01h  1
#   72 -2.4928976e+01 2.66e-15 1.17e+00  -8.6 1.23e+01    -  9.14e-01 1.00e+00h  1
#   73 -2.4928976e+01 1.75e-08 8.58e-01  -8.6 9.87e+01    -  8.26e-01 1.00e+00h  1
#   74 -2.4928976e+01 8.88e-15 3.63e+01  -8.6 9.90e+02    -  2.42e-01 1.00e+00h  1
#   75 -2.4928976e+01 5.68e-14 2.94e-01  -8.6 2.44e-07  -1.1 5.81e-01 1.00e+00h  1
#   76 -2.4928976e+01 8.53e-14 2.87e+00  -8.6 1.52e+03    -  8.18e-01 1.00e+00h  1
#   77 -2.4928976e+01 1.21e-13 2.87e+00  -8.6 1.46e-03  -1.6 3.08e-01 3.66e-04h  2
#   78 -2.4928976e+01 3.05e-06 9.50e+00  -8.6 5.33e+03    -  5.79e-01 1.00e+00h  1
#   79 -2.4928976e+01 1.99e-13 8.42e-09  -8.6 9.96e-07  -2.1 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 79
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -2.4928976003218104e+01   -2.4928976003218104e+01
# Dual infeasibility......:   8.4227761990495961e-09    8.4227761990495961e-09
# Constraint violation....:   1.9895196601282805e-13    1.9895196601282805e-13
# Variable bound violation:   4.9510173327651507e-09    4.9510173327651507e-09
# Complementarity.........:   2.5059484304684947e-09    2.5059484304684947e-09
# Overall NLP error.......:   8.4227761990495961e-09    8.4227761990495961e-09
#
#
# Number of objective function evaluations             = 97
# Number of objective gradient evaluations             = 76
# Number of equality constraint evaluations            = 97
# Number of inequality constraint evaluations          = 97
# Number of equality constraint Jacobian evaluations   = 81
# Number of inequality constraint Jacobian evaluations = 81
# Number of Lagrangian Hessian evaluations             = 79
# Total seconds in IPOPT                               = 0.008
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.7.3.
#
# Number of nonzeros in equality constraint Jacobian...:       10
# Number of nonzeros in inequality constraint Jacobian.:       41
# Number of nonzeros in Lagrangian Hessian.............:       13
#
# Total number of variables............................:       10
#                      variables with only lower bounds:        6
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        4
# Total number of equality constraints.................:        2
# Total number of inequality constraints...............:       10
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       10
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -4.9999950e-03 4.83e+01 2.19e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.9978535e-03 4.83e+01 2.30e+00  -1.0 4.37e+01    -  4.00e-03 2.49e-03h  1
# El DataFrame ha sido guardado en ex9.1.10(Linear)_alpha_non_zero.xlsx en la hoja ex9.1.10(Linear)_alpha_non_zero.
